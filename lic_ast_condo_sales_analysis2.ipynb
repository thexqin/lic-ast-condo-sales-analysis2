# %% [markdown]
# # df

# %%
# @title load

import pandas as pd
import requests
import json
from IPython.display import display, Markdown

DATA_URL = 'data.cityofnewyork.us'
DATA_SET = '8y4t-faws'

def check(aptno):
    url = 'https://data.cityofnewyork.us/resource/8y4t-faws.json'

    r = requests.get(f'{url}?housenum_lo=23-15&street_name=44TH DRIVE&aptno={aptno}&$$app_token={APP_TOKEN}&$order=year ASC')
    j = r.json()

    display(df[df.aptno == aptno])

    for i in j:
        print(f"{i['year']}: {i['owner']}")

df = pd.read_csv('23-15.csv', parse_dates=['SALE DATE'])
df.info()

# %%
aptno_sorted = sorted(list(df['aptno'].unique()), key=lambda x: (1, int(x[2:])) if x.startswith('PH') else (0, int(x)))
aptno_sorted[:10]
# Out:
# ['301', '303', '304', '305', '306', '307', '308', '309', '310', '311']

# %%
len(aptno_sorted)
# Out:
# 751

# %%
aptno_sorted[-10:]
# Out:
# ['PH302',
#  'PH303',
#  'PH304',
#  'PH305',
#  'PH306',
#  'PH307',
#  'PH308',
#  'PH309',
#  'PH406',
#  'PH408']

# %% [markdown]
# # ph

# %%
for i in aptno_sorted:
    if i.startswith('PH'):
        check(i)
# Out:
#      ZIP CODE  YEAR BUILT  SALE PRICE  SALE DATE housenum  streetname  aptno  \
# 150     11101        2018     2480850 2023-12-15    23-15  44TH DRIVE  PH102
#
#       sqft  $/sqft               owner  curtxbtot
# 150  986.0  2516.0  COURT SQUARE 3 LLC     133679
# 2023: BGY CITYVIEW LLC
# 2023: BGY CITYVIEW LLC
# 2024: COURT SQUARE PROPERTY LLC
# 2024: COURT SQUARE PROPERTY LLC
# 2025: COURT SQUARE 3 LLC
# 2025: COURT SQUARE 3 LLC
# 2026: COURT SQUARE 3 LLC
# 2026: COURT SQUARE 3 LLC
#      ZIP CODE  YEAR BUILT  SALE PRICE  SALE DATE housenum  streetname  aptno  \
# 358     11101        2018   161342986 2022-07-13    23-15  44TH DRIVE  PH201
#
#       sqft    $/sqft                 owner  curtxbtot
# 358  969.0  166505.0  RISLAND NEW YORK LLC     131329
# 2023: BGY CITYVIEW LLC
# 2023: BGY CITYVIEW LLC
# 2024: RISLAND NEW YORK LLC
# 2024: RISLAND NEW YORK LLC
# 2025: RISLAND NEW YORK LLC
# 2025: RISLAND NEW YORK LLC
# 2026: RISLAND NEW YORK LLC
# 2026: RISLAND NEW YORK LLC
# ...

# %%
df[df.aptno == 'PH408']
# Out:
#     ZIP CODE  YEAR BUILT  SALE PRICE  SALE DATE housenum  streetname  aptno  \
# 13     11101        2018     2649700 2025-03-12    23-15  44TH DRIVE  PH408
#
#      sqft  $/sqft               owner  curtxbtot
# 13  470.0  5638.0  HOLDING 12 SUB LLC     179609

# %%
df[df.owner.str.contains('P GUO', case=False)]
# Out:
#      ZIP CODE  YEAR BUILT  SALE PRICE  SALE DATE housenum  streetname aptno  \
# 687     11101        2018     2410778 2021-08-13    23-15  44TH DRIVE  4011
#
#        sqft  $/sqft       owner  curtxbtot
# 687  1326.0  1818.0  P GUO, LLC     182353

# %% [markdown]
# # corporate

# %%
# @title check bulk
def check_bulk(price):
    sub = df[df['SALE PRICE'] == price]

    display(sub)

    display(sub['SALE DATE'].value_counts())


    print(f"\nprice/sqft sum: {round(sub['SALE PRICE'].values[0] / sub['sqft'].sum(), 2)}")

# %%
df['SALE PRICE'].value_counts().sort_index(ascending=False).head(15)
# Out:
# SALE PRICE
# 161342986    106
# 21400000      13
# 15427300      12
# 3738805        2
# 3230318        3
# 3188863        2
# 3113288        2
# 2900000        1
# 2728910        1
# 2710009        2
# 2702744        2
# 2695480        1
# 2659034        1
# 2649700        1
# 2610739        1
# Name: count, dtype: int64

# %%
check_bulk(161342986)
# Out:
#      ZIP CODE  YEAR BUILT  SALE PRICE  SALE DATE housenum  streetname aptno  \
# 295     11101        2018   161342986 2022-07-13    23-15  44TH DRIVE  4711
# 296     11101        2018   161342986 2022-07-13    23-15  44TH DRIVE  4706
# 297     11101        2018   161342986 2022-07-13    23-15  44TH DRIVE   619
# 298     11101        2018   161342986 2022-07-13    23-15  44TH DRIVE   617
# 299     11101        2018   161342986 2022-07-13    23-15  44TH DRIVE  6303
# ..        ...         ...         ...        ...      ...         ...   ...
# 400     11101        2018   161342986 2022-07-13    23-15  44TH DRIVE  2809
# 401     11101        2018   161342986 2022-07-13    23-15  44TH DRIVE  4211
# 402     11101        2018   161342986 2022-07-13    23-15  44TH DRIVE  5801
# 403     11101        2018   161342986 2022-07-13    23-15  44TH DRIVE  5910
# 404     11101        2018   161342986 2022-07-13    23-15  44TH DRIVE  3403
#
#        sqft    $/sqft                  owner  curtxbtot
# ...

# %%
check_bulk(21400000)
# Out:
#      ZIP CODE  YEAR BUILT  SALE PRICE  SALE DATE housenum  streetname aptno  \
# 93      11101        2018    21400000 2024-05-09    23-15  44TH DRIVE  4401
# 94      11101        2018    21400000 2024-05-09    23-15  44TH DRIVE  4411
# 95      11101        2018    21400000 2024-05-09    23-15  44TH DRIVE  4109
# 96      11101        2018    21400000 2024-05-09    23-15  44TH DRIVE  3809
# 97      11101        2018    21400000 2024-05-09    23-15  44TH DRIVE  3301
# 98      11101        2018    21400000 2024-05-09    23-15  44TH DRIVE  3112
# 99      11101        2018    21400000 2024-05-09    23-15  44TH DRIVE  3102
# 100     11101        2018    21400000 2024-05-09    23-15  44TH DRIVE  6111
# 101     11101        2018    21400000 2024-05-09    23-15  44TH DRIVE  5211
# 102     11101        2018    21400000 2024-05-09    23-15  44TH DRIVE  2608
# 103     11101        2018    21400000 2024-05-09    23-15  44TH DRIVE  4802
# ...

# %%
check_bulk(15427300)
# Out:
#      ZIP CODE  YEAR BUILT  SALE PRICE  SALE DATE housenum  streetname aptno  \
# 263     11101        2018    15427300 2022-09-14    23-15  44TH DRIVE  6207
# 264     11101        2018    15427300 2022-09-14    23-15  44TH DRIVE  4906
# 265     11101        2018    15427300 2022-09-14    23-15  44TH DRIVE  5208
# 266     11101        2018    15427300 2022-09-14    23-15  44TH DRIVE  5311
# 267     11101        2018    15427300 2022-09-14    23-15  44TH DRIVE  6002
# 268     11101        2018    15427300 2022-09-14    23-15  44TH DRIVE  6201
# 269     11101        2018    15427300 2022-09-14    23-15  44TH DRIVE  6004
# 270     11101        2018    15427300 2022-09-14    23-15  44TH DRIVE  2006
# 271     11101        2018    15427300 2022-09-14    23-15  44TH DRIVE   414
# 272     11101        2018    15427300 2022-09-14    23-15  44TH DRIVE  5212
# 273     11101        2018    15427300 2022-09-14    23-15  44TH DRIVE   419
# ...

# %%
# not make sense
check_bulk(3738805)
# Out:
#     ZIP CODE  YEAR BUILT  SALE PRICE  SALE DATE housenum  streetname  aptno  \
# 22     11101        2018     3738805 2024-12-18    23-15  44TH DRIVE  PH406
# 23     11101        2018     3738805 2024-12-18    23-15  44TH DRIVE  PH406
#
#      sqft  $/sqft        owner  curtxbtot
# 22  470.0  7955.0  LAMNG CORP.     209774
# 23  470.0  7955.0  LAMNG CORP.     209774
# SALE DATE
# 2024-12-18    2
# Name: count, dtype: int64
# price/sqft sum: 3977.45

# %%
check_bulk(3230318)
# Out:
#      ZIP CODE  YEAR BUILT  SALE PRICE  SALE DATE housenum  streetname aptno  \
# 864     11101        2018     3230318 2021-03-29    23-15  44TH DRIVE  1402
# 865     11101        2018     3230318 2021-03-29    23-15  44TH DRIVE   807
# 866     11101        2018     3230318 2021-03-29    23-15  44TH DRIVE   601
#
#       sqft  $/sqft                             owner  curtxbtot
# 864  997.0  3240.0  THE BENITO BARBA TRUST AGREEMENT     135149
# 865  704.0  4589.0  THE BENITO BARBA TRUST AGREEMENT      95485
# 866  644.0  5016.0  THE BENITO BARBA TRUST AGREEMENT      87357
# SALE DATE
# 2021-03-29    3
# Name: count, dtype: int64
# price/sqft sum: 1377.53

# %%
check_bulk(3188863)
# Out:
#      ZIP CODE  YEAR BUILT  SALE PRICE  SALE DATE housenum  streetname aptno  \
# 525     11101        2018     3188863 2022-02-25    23-15  44TH DRIVE  2312
# 526     11101        2018     3188863 2022-02-25    23-15  44TH DRIVE  2311
#
#        sqft  $/sqft             owner  curtxbtot
# 525   672.0  4745.0  MADAN, KULDEEP S          0
# 526  1272.0  2507.0  MADAN, KULDEEP S     263538
# SALE DATE
# 2022-02-25    2
# Name: count, dtype: int64
# price/sqft sum: 1640.36

# %%
# not make sense
check_bulk(3113288)
# Out:
#     ZIP CODE  YEAR BUILT  SALE PRICE  SALE DATE housenum  streetname  aptno  \
# 74     11101        2018     3113288 2024-06-25    23-15  44TH DRIVE  PH208
# 77     11101        2018     3113288 2024-06-25    23-15  44TH DRIVE  PH208
#
#      sqft  $/sqft               owner  curtxbtot
# 74  470.0  6624.0  LPA PROPERTY TRUST     179609
# 77  470.0  6624.0  LPA PROPERTY TRUST     179609
# SALE DATE
# 2024-06-25    2
# Name: count, dtype: int64
# price/sqft sum: 3312.01

# %%
check_bulk(2710009)
# Out:
#     ZIP CODE  YEAR BUILT  SALE PRICE  SALE DATE housenum  streetname aptno  \
# 18     11101        2018     2710009 2024-12-27    23-15  44TH DRIVE  5911
# 19     11101        2018     2710009 2024-12-27    23-15  44TH DRIVE  5911
#
#       sqft  $/sqft                 owner  curtxbtot
# 18  1326.0  2044.0  RISLAND NEW YORK LLC     179804
# 19  1326.0  2044.0  RISLAND NEW YORK LLC     179804
# SALE DATE
# 2024-12-27    2
# Name: count, dtype: int64
# price/sqft sum: 1021.87

# %%
check_bulk(2702744)
# Out:
#     ZIP CODE  YEAR BUILT  SALE PRICE  SALE DATE housenum  streetname aptno  \
# 64     11101        2018     2702744 2024-07-29    23-15  44TH DRIVE  5811
# 65     11101        2018     2702744 2024-07-29    23-15  44TH DRIVE  5811
#
#       sqft  $/sqft                   owner  curtxbtot
# 64  1326.0  2038.0  SUMMER BROOK GROUP LLC     179804
# 65  1326.0  2038.0  SUMMER BROOK GROUP LLC     179804
# SALE DATE
# 2024-07-29    2
# Name: count, dtype: int64
# price/sqft sum: 1019.13

# %%
df[df['SALE PRICE'] == 2900000]
# Out:
#      ZIP CODE  YEAR BUILT  SALE PRICE  SALE DATE housenum  streetname  aptno  \
# 236     11101        2018     2900000 2023-02-17    23-15  44TH DRIVE  PH308
#
#       sqft  $/sqft                  owner  curtxbtot
# 236  470.0  6170.0  SKYLINE UNIVERSAL LLC     179609

# %%
df[df['SALE PRICE'] == 2728910]
# Out:
#     ZIP CODE  YEAR BUILT  SALE PRICE  SALE DATE housenum  streetname aptno  \
# 91     11101        2018     2728910 2024-05-17    23-15  44TH DRIVE  5511
#
#       sqft  $/sqft            owner  curtxbtot
# 91  1326.0  2058.0  SUMMERWINGS LLC     179804

# %%
df[df['SALE PRICE'] == 2695480]
# Out:
#      ZIP CODE  YEAR BUILT  SALE PRICE  SALE DATE housenum  streetname aptno  \
# 181     11101        2018     2695480 2023-09-26    23-15  44TH DRIVE  5711
#
#        sqft  $/sqft                         owner  curtxbtot
# 181  1326.0  2033.0  DE JUNIAC, PHILIPPE BEGOUGNE     179804

# %%
df[df['SALE PRICE'] < 500000]
# Out:
#      ZIP CODE  YEAR BUILT  SALE PRICE  SALE DATE housenum  streetname aptno  \
# 5       11101        2018       36389 2025-05-08    23-15  44TH DRIVE  2002
# 14      11101        2018       30178 2025-03-07    23-15  44TH DRIVE  3109
# 42      11101        2018       28448 2024-10-17    23-15  44TH DRIVE   630
# 43      11101        2018       28448 2024-10-17    23-15  44TH DRIVE   630
# 44      11101        2018       27741 2024-10-04    23-15  44TH DRIVE  4202
# 45      11101        2018       27741 2024-10-04    23-15  44TH DRIVE  4202
# 212     11101        2018      492000 2023-06-06    23-15  44TH DRIVE   404
# 646     11101        2018          10 2021-09-18    23-15  44TH DRIVE  1606
#
#       sqft  $/sqft                 owner  curtxbtot
# 5    997.0    36.0           LIU, YUZHUI     135149
# 14   625.0    48.0             MO, DIKUN      84712
# 42   665.0    43.0  YELLOW HOMESTEAD LLC      90197
# 43   665.0    43.0  YELLOW HOMESTEAD LLC      90197
# ...

# %% [markdown]
# # df2

# %%
df2 = df[(df['SALE PRICE'] >= 492000) & (df['SALE PRICE'] <= 2695480) & ~df['aptno'].str.startswith('PH')].copy()
df2
# Out:
#      ZIP CODE  YEAR BUILT  SALE PRICE  SALE DATE housenum  streetname aptno  \
# 2       11101        2018     1980973 2025-05-16    23-15  44TH DRIVE  6012
# 3       11101        2018     1100000 2025-05-12    23-15  44TH DRIVE   907
# 4       11101        2018     1187500 2025-05-09    23-15  44TH DRIVE  3609
# 6       11101        2018      845086 2025-04-30    23-15  44TH DRIVE   521
# 7       11101        2018     1160000 2025-04-17    23-15  44TH DRIVE  4805
# ..        ...         ...         ...        ...      ...         ...   ...
# 895     11101        2018     1681381 2021-02-10    23-15  44TH DRIVE  1211
# 896     11101        2018      937488 2021-02-09    23-15  44TH DRIVE  2509
# 897     11101        2018      959757 2021-02-09    23-15  44TH DRIVE  3209
# 898     11101        2018     1108437 2021-02-08    23-15  44TH DRIVE  4203
# 899     11101        2018      919113 2020-07-06    23-15  44TH DRIVE  2304
#
#        sqft  $/sqft                  owner  curtxbtot
# ...

# %%
df2.describe()
# Out:
#        ZIP CODE  YEAR BUILT    SALE PRICE                      SALE DATE  \
# count     741.0       741.0  7.410000e+02                            741
# mean    11101.0      2018.0  1.271230e+06  2022-06-27 21:16:45.668016384
# min     11101.0      2018.0  4.920000e+05            2020-07-06 00:00:00
# 25%     11101.0      2018.0  9.687730e+05            2021-07-30 00:00:00
# 50%     11101.0      2018.0  1.200278e+06            2022-02-28 00:00:00
# 75%     11101.0      2018.0  1.562939e+06            2023-05-18 00:00:00
# max     11101.0      2018.0  2.695480e+06            2025-05-16 00:00:00
# std         0.0         0.0  3.987397e+05                            NaN
#
#               sqft       $/sqft      curtxbtot
# count   741.000000   741.000000     741.000000
# mean    796.995951  1600.036437  108425.195682
# min     400.000000  1126.000000   54254.000000
# 25%     635.000000  1427.000000   87651.000000
# 50%     724.000000  1587.000000   98128.000000
# ...

# %%
df2[df2['$/sqft'] > 2500]
# Out:
#      ZIP CODE  YEAR BUILT  SALE PRICE  SALE DATE housenum  streetname aptno  \
# 168     11101        2018     1444739 2023-11-09    23-15  44TH DRIVE  2206
# 169     11101        2018     1444739 2023-11-09    23-15  44TH DRIVE  2306
#
#       sqft  $/sqft                  owner  curtxbtot
# 168  420.0  3440.0  3 CV COURT SQUARE LLC      56898
# 169  420.0  3440.0  3 CV COURT SQUARE LLC      56898

# %%
df2 = df[(df['SALE PRICE'] >= 492000) &
         (df['SALE PRICE'] <= 2695480) &
         (df['$/sqft'] <= 2500) &
         ~df['aptno'].str.startswith('PH')
         ].copy()
df2
# Out:
#      ZIP CODE  YEAR BUILT  SALE PRICE  SALE DATE housenum  streetname aptno  \
# 2       11101        2018     1980973 2025-05-16    23-15  44TH DRIVE  6012
# 3       11101        2018     1100000 2025-05-12    23-15  44TH DRIVE   907
# 4       11101        2018     1187500 2025-05-09    23-15  44TH DRIVE  3609
# 6       11101        2018      845086 2025-04-30    23-15  44TH DRIVE   521
# 7       11101        2018     1160000 2025-04-17    23-15  44TH DRIVE  4805
# ..        ...         ...         ...        ...      ...         ...   ...
# 895     11101        2018     1681381 2021-02-10    23-15  44TH DRIVE  1211
# 896     11101        2018      937488 2021-02-09    23-15  44TH DRIVE  2509
# 897     11101        2018      959757 2021-02-09    23-15  44TH DRIVE  3209
# 898     11101        2018     1108437 2021-02-08    23-15  44TH DRIVE  4203
# 899     11101        2018      919113 2020-07-06    23-15  44TH DRIVE  2304
#
#        sqft  $/sqft                  owner  curtxbtot
# ...

# %%
df2 = df2[~df2.duplicated()].copy()
df2
# Out:
#      ZIP CODE  YEAR BUILT  SALE PRICE  SALE DATE housenum  streetname aptno  \
# 2       11101        2018     1980973 2025-05-16    23-15  44TH DRIVE  6012
# 3       11101        2018     1100000 2025-05-12    23-15  44TH DRIVE   907
# 4       11101        2018     1187500 2025-05-09    23-15  44TH DRIVE  3609
# 6       11101        2018      845086 2025-04-30    23-15  44TH DRIVE   521
# 7       11101        2018     1160000 2025-04-17    23-15  44TH DRIVE  4805
# ..        ...         ...         ...        ...      ...         ...   ...
# 895     11101        2018     1681381 2021-02-10    23-15  44TH DRIVE  1211
# 896     11101        2018      937488 2021-02-09    23-15  44TH DRIVE  2509
# 897     11101        2018      959757 2021-02-09    23-15  44TH DRIVE  3209
# 898     11101        2018     1108437 2021-02-08    23-15  44TH DRIVE  4203
# 899     11101        2018      919113 2020-07-06    23-15  44TH DRIVE  2304
#
#        sqft  $/sqft                  owner  curtxbtot
# ...

# %%
df2.boxplot(column=['SALE PRICE'], vert=False, grid=False, figsize=(10, 2))
# Out:
# <Axes: >

# %%
df2.boxplot(column=['$/sqft'], vert=False, grid=False, figsize=(10, 2))
# Out:
# <Axes: >

# %% [markdown]
# # resale

# %%
# @title load

import pandas as pd
import numpy as np
import requests
import json
from IPython.display import display, Markdown

df = pd.read_csv('23-15sub.csv', parse_dates=['SALE DATE'])

# %%
df = df[df.duplicated('aptno', False)].sort_values(['aptno', 'SALE DATE'], ascending=[True, False]).reset_index(drop=True).copy()
df
# Out:
#     ZIP CODE  YEAR BUILT  SALE PRICE  SALE DATE housenum  streetname  aptno  \
# 0      11101        2018      492000 2023-06-06    23-15  44TH DRIVE    404
# 1      11101        2018      718772 2023-04-11    23-15  44TH DRIVE    404
# 2      11101        2018      705000 2024-10-29    23-15  44TH DRIVE    516
# 3      11101        2018      673114 2021-06-18    23-15  44TH DRIVE    516
# 4      11101        2018     1180000 2024-07-30    23-15  44TH DRIVE    805
# 5      11101        2018     1218970 2021-06-02    23-15  44TH DRIVE    805
# 6      11101        2018     1100000 2025-05-12    23-15  44TH DRIVE    907
# 7      11101        2018      929255 2022-07-14    23-15  44TH DRIVE    907
# 8      11101        2018     2240000 2024-11-01    23-15  44TH DRIVE   1611
# 9      11101        2018     1862500 2021-03-24    23-15  44TH DRIVE   1611
# 10     11101        2018     1681875 2024-11-22    23-15  44TH DRIVE   1702
# ...

# %%
df = df[df.aptno != 404].reset_index(drop=True).copy()
df.head()
# Out:
#    ZIP CODE  YEAR BUILT  SALE PRICE  SALE DATE housenum  streetname  aptno  \
# 0     11101        2018      705000 2024-10-29    23-15  44TH DRIVE    516
# 1     11101        2018      673114 2021-06-18    23-15  44TH DRIVE    516
# 2     11101        2018     1180000 2024-07-30    23-15  44TH DRIVE    805
# 3     11101        2018     1218970 2021-06-02    23-15  44TH DRIVE    805
# 4     11101        2018     1100000 2025-05-12    23-15  44TH DRIVE    907
#
#     sqft  $/sqft                owner  curtxbtot
# 0  425.0  1659.0         CHEN, YITONG      57584
# 1  425.0  1584.0         CHEN, YITONG      57584
# 2  932.0  1266.0           HC805 INC.     124963
# 3  932.0  1308.0           HC805 INC.     124963
# 4  704.0  1562.0  WONG, ADAM GAH JUIN      95485

# %%
for i in df.aptno.unique():
    check(i)
# Out:
#    ZIP CODE  YEAR BUILT  SALE PRICE  SALE DATE housenum  streetname  aptno  \
# 0     11101        2018      705000 2024-10-29    23-15  44TH DRIVE    516
# 1     11101        2018      673114 2021-06-18    23-15  44TH DRIVE    516
#
#     sqft  $/sqft         owner  curtxbtot
# 0  425.0  1659.0  CHEN, YITONG      57584
# 1  425.0  1584.0  CHEN, YITONG      57584
# 2023: DONG, TAO
# 2023: "DONG, TAO                                                                       "
# 2024: DONG, TAO
# 2024: DONG, TAO
# 2025: DONG, TAO
# 2025: DONG, TAO
# 2026: CHEN, YITONG
# 2026: CHEN, YITONG
#    ZIP CODE  YEAR BUILT  SALE PRICE  SALE DATE housenum  streetname  aptno  \
# 2     11101        2018     1180000 2024-07-30    23-15  44TH DRIVE    805
# 3     11101        2018     1218970 2021-06-02    23-15  44TH DRIVE    805
#
#     sqft  $/sqft       owner  curtxbtot
# 2  932.0  1266.0  HC805 INC.     124963
# 3  932.0  1308.0  HC805 INC.     124963
# 2023: LONG, ALEXANDRA LINSLEY
# ...

# %%
df['changeM'] = np.nan
df['change$'] = np.nan
df['change%'] = np.nan

for i in range(0, len(df), 2):
    temp = df.loc[i, 'SALE DATE'] - df.loc[i+1, 'SALE DATE']
    df.loc[i, 'changeM'] = temp.days / 30
    df.loc[i, 'change$'] = df.loc[i, 'SALE PRICE'] - df.loc[i+1, 'SALE PRICE']
    df.loc[i, 'change%'] = df.loc[i, 'SALE PRICE'] / df.loc[i+1, 'SALE PRICE']

df
# Out:
#     ZIP CODE  YEAR BUILT  SALE PRICE  SALE DATE housenum  streetname  aptno  \
# 0      11101        2018      705000 2024-10-29    23-15  44TH DRIVE    516
# 1      11101        2018      673114 2021-06-18    23-15  44TH DRIVE    516
# 2      11101        2018     1180000 2024-07-30    23-15  44TH DRIVE    805
# 3      11101        2018     1218970 2021-06-02    23-15  44TH DRIVE    805
# 4      11101        2018     1100000 2025-05-12    23-15  44TH DRIVE    907
# 5      11101        2018      929255 2022-07-14    23-15  44TH DRIVE    907
# 6      11101        2018     2240000 2024-11-01    23-15  44TH DRIVE   1611
# 7      11101        2018     1862500 2021-03-24    23-15  44TH DRIVE   1611
# 8      11101        2018     1681875 2024-11-22    23-15  44TH DRIVE   1702
# 9      11101        2018     1535241 2021-02-17    23-15  44TH DRIVE   1702
# 10     11101        2018     1760000 2025-03-14    23-15  44TH DRIVE   2202
# ...

# %%
df['change%'].describe()
# Out:
# count    16.000000
# mean      1.052732
# std       0.136714
# min       0.656699
# 25%       1.012243
# 50%       1.052083
# 75%       1.141820
# max       1.212373
# Name: change%, dtype: float64

# %%
df[df['change%'] > 0.8].boxplot('change%', vert=False, grid=False, figsize=(10, 2))
# Out:
# <Axes: >

# %%
df['change%'].notna().sum()
# Out:
# np.int64(16)

# %%
(df['change%']>1).sum()
# Out:
# np.int64(12)

# %%
df['change$'].describe()
# Out:
# count        16.000000
# mean      46582.125000
# std      257982.012611
# min     -795630.000000
# 25%       14154.750000
# 50%       66400.000000
# 75%      171100.000000
# max      377500.000000
# Name: change$, dtype: float64

# %%
df[df['change$'] > -400000].boxplot('change$', vert=False, grid=False, figsize=(10, 2))
# Out:
# <Axes: >

# %%
df['changeM'].describe()
# Out:
# count    16.000000
# mean     33.197917
# std      10.868347
# min      13.200000
# 25%      26.783333
# 50%      34.850000
# 75%      41.700000
# max      47.200000
# Name: changeM, dtype: float64

# %%
df.boxplot('changeM', vert=False, grid=False, figsize=(10, 2))
# Out:
# <Axes: >

# %%
df2 = df.dropna()
df2 = df2[df2['change%'] > 0.8]
df2 = df2.reset_index(drop=True).copy()
df2
# Out:
#     ZIP CODE  YEAR BUILT  SALE PRICE  SALE DATE housenum  streetname  aptno  \
# 0      11101        2018      705000 2024-10-29    23-15  44TH DRIVE    516
# 1      11101        2018     1180000 2024-07-30    23-15  44TH DRIVE    805
# 2      11101        2018     1100000 2025-05-12    23-15  44TH DRIVE    907
# 3      11101        2018     2240000 2024-11-01    23-15  44TH DRIVE   1611
# 4      11101        2018     1681875 2024-11-22    23-15  44TH DRIVE   1702
# 5      11101        2018     1760000 2025-03-14    23-15  44TH DRIVE   2202
# 6      11101        2018     1175000 2024-08-30    23-15  44TH DRIVE   2612
# 7      11101        2018     1115000 2023-07-12    23-15  44TH DRIVE   2909
# 8      11101        2018     1187500 2025-05-09    23-15  44TH DRIVE   3609
# 9      11101        2018     1770000 2024-09-25    23-15  44TH DRIVE   4002
# 10     11101        2018     1795000 2024-05-06    23-15  44TH DRIVE   4301
# ...

# %%
df3 = df2.copy()
df3['change%'] = df3['change%'] -1
ax = df3.sort_values('change%').plot.bar(x='aptno', y='change%', figsize=(10, 3), grid=True, rot=30)
ax.grid(color='gray', linestyle='-', linewidth=0.5, alpha=0.4)
ax.set_title('apt resale % gain')
ax.set_axisbelow(True)

# %%
ax = df2.sort_values('change%').plot.bar(x='aptno', y='change$', figsize=(10, 3), grid=True, rot=30)
ax.grid(color='gray', linestyle='-', linewidth=0.5, alpha=0.4)
ax.set_title('apt resale $ gain')
ax.set_axisbelow(True)

# %%
ax = df2.sort_values('change%').plot.bar(x='aptno', y='changeM', figsize=(10, 3), grid=True, rot=30)
ax.grid(color='gray', linestyle='-', linewidth=0.5, alpha=0.4)
ax.set_title('apt resale after # of months')
ax.set_axisbelow(True)
